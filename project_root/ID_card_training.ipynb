# %% [markdown]
# # **Program for training the YOLOv8 with custom dataset**

# %%
# connect to your Google drive
from google.colab import drive
drive.mount('/content/drive')

# change to the YOLOv8 or your project directory
# mine was Yolov8_id_main
# %cd /content/drive/MyDrive/Yolov8_id_main/

# %% [markdown]
# # **LOADING YOLOv8 PRE-TRAINED MODEL FOR TRAINING ON CUSTOM DATASET**

# %%
# installing required packages for working on YOLOv8
# !pip install ultralytics
from ultralytics import YOLO

# %%
# loading the pre-trained model yolov8x.pt
# yolov8x.pt should be kept in root directory of your project
model = YOLO("yolov8n.pt")

# start tarining with data_custom.yaml file and required epochs according to your dataset
# data_custom.yaml should be kept in root directory of your project

model.train(data = "data_custom.yaml", imgsz=640, epochs=100)

# after training the weights.pt file will save in root directory of your project
